# %%
from dataLoad import load_mnist
from attack import PoisoningAttackBackdoor
from utils import preprocess

import numpy as np
import tensorflow as tf
from PIL import Image
import matplotlib.pylab as plt
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout
from art.estimators.classification import KerasClassifier
import sys

# %%
"""
x_raw: 数据集
y_raw: label
"""
(x_raw, y_raw), (x_raw_test, y_raw_test), min_x, max_x = load_mnist()  # todo
n_train = np.shape(x_raw)[0] # num_img
print(n_train)
select_count = 7500 # num_selection 
selection_indices = np.random.choice(n_train, select_count)
x_raw = x_raw[selection_indices]
y_raw = y_raw[selection_indices]
# Out:
# 60000

# %%
max_val = np.max(x_raw) # specify a padding value
print(max_val)
# Out:
# 255

# %%
def add_pattern_bd(x: np.ndarray, distance: int = 2, pixel_value: int = max_val) -> np.ndarray: 
    """
    x: matrix
    distance: 距离
    pixel_value: 用于替换的值
    return: 处理后的图像
    """
    x = np.array(x)
    shape = x.shape
    if len(shape) == 4: # 多图多色阶
        width, height = x.shape[1:3]
        x[:, width - distance, height - distance, :] = pixel_value
        x[:, width - distance - 1, height - distance - 1, :] = pixel_value
        x[:, width - distance, height - distance - 2, :] = pixel_value
        x[:, width - distance - 2, height - distance, :] = pixel_value
    elif len(shape) == 3: # 多图单色阶
        width, height = x.shape[1:]
        x[:, width - distance, height - distance] = pixel_value
        x[:, width - distance - 1, height - distance - 1] = pixel_value
        x[:, width - distance, height - distance - 2] = pixel_value
        x[:, width - distance - 2, height - distance] = pixel_value
    elif len(shape) == 2: # 单图
        width, height = x.shape
        x[:, width - distance, height - distance] = pixel_value
        x[:, width - distance - 1, height - distance - 1] = pixel_value
        x[:, width - distance, height - distance - 2] = pixel_value
        x[:, width - distance - 2, height - distance] = pixel_value
    else:
        raise ValueError("Invalid array shape: " + str(shape))
    return x

def poison_dataset(x_clean, y_clean, percent_poison, poison_func):
    
    x_poison = np.copy(x_clean)
    y_poison = np.copy(y_clean)
    is_poison = np.zeros(np.shape(y_poison))


    sources = np.array([0])
    targets = np.array([1])
    # sources = np.arange(10)
    # target = (np.arange(10) + 1) % 10
    for i, (src, tgt) in enumerate(zip(sources, targets)):
        n_point_in_tgt = np.size(np.where(y_clean == tgt)) # total tgt_num
        num_poison = round((percent_poison * n_point_in_tgt) / (1 - percent_poison))
        src_img = x_clean[y_clean == src] # img to be poisoned

        n_point_in_src = np.shape(src_img)[0]
        indices_to_be_poisoned = np.random.choice(n_point_in_src, num_poison) # select
        imgs_to_be_poisoned = np.copy(src_img[indices_to_be_poisoned])

        backdoor_attack = PoisoningAttackBackdoor(poison_func) # add_pattern_bd
        imgs_to_be_poisoned, poison_labels = backdoor_attack.poison(imgs_to_be_poisoned, y=np.ones(num_poison) * tgt)
        x_poison = np.append(x_poison, imgs_to_be_poisoned, axis=0)
        y_poison = np.append(y_poison, poison_labels, axis=0)
        is_poison = np.append(is_poison, np.ones(num_poison))

    is_poison = is_poison != 0

    return is_poison, x_poison, y_poison

# %%
# poison
percent_poison = .33
(is_poison_train, x_poisoned_raw, y_poisoned_raw) = poison_dataset(x_raw, y_raw, percent_poison, add_pattern_bd)

# %%
# print(len(x_poisoned_raw))
# for i in range(len((x_poisoned_raw))):
#     new_im = Image.fromarray(x_poisoned_raw[i,:,:])
#     plt.imsave('./img/' + str(i) + '.jpg', new_im)
new_im = Image.fromarray(x_poisoned_raw[7822,:,:])
plt.imshow(new_im)

# %%
# 归一化
x_train, y_train = preprocess(x_poisoned_raw, y_poisoned_raw)
# Add channel axis:
x_train = np.expand_dims(x_train, axis=3)

# %%
# poison test data
(is_poison_test, x_poisoned_raw_test, y_poisoned_raw_test) = poison_dataset(x_raw_test, y_raw_test, percent_poison, add_pattern_bd)

# %%
# 查看图片
print(len(x_poisoned_raw_test))
# for i in range(len((x_poisoned_raw_test))):
#     new_im = Image.fromarray(x_poisoned_raw_test[i,:,:])
#     plt.imsave('./img_test/' + str(i) + '.jpg', new_im)
# Out:
# 10559

# %%
x_test, y_test = preprocess(x_poisoned_raw_test, y_poisoned_raw_test)
x_test = np.expand_dims(x_test, axis=3)

# %%
# 打乱数据
n_train = np.shape(y_train)[0]
shuffled_indices = np.arange(n_train)
np.random.shuffle(shuffled_indices)
x_train = x_train[shuffled_indices]
y_train = y_train[shuffled_indices]

# %%
# build cnn
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=x_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# disable tf eager execution
tf.compat.v1.disable_eager_execution()
sys.setrecursionlimit(3000)
classifier = KerasClassifier(model=model, clip_values=(min_x, max_x))
classifier.fit(x_train, y_train, nb_epochs=5, batch_size=128)
# Out:
# Train on 7921 samples
# Epoch 1/5
# 2022-10-25 22:33:05.960037: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 7921/7921 [==============================] - 4s 550us/sample - loss: 0.8163 - accuracy: 0.7327
# Epoch 2/5
# 7921/7921 [==============================] - 4s 534us/sample - loss: 0.2736 - accuracy: 0.9169
# Epoch 3/5
# 7921/7921 [==============================] - 4s 534us/sample - loss: 0.1729 - accuracy: 0.9490
# Epoch 4/5
# 7921/7921 [==============================] - 4s 536us/sample - loss: 0.1234 - accuracy: 0.9644
# Epoch 5/5
# 7921/7921 [==============================] - 4s 530us/sample - loss: 0.0939 - accuracy: 0.9700

# %% [markdown]
# 【插一个fit进度/tao/Snipaste_2022-10-25_16-18-06.png】

# %%
clean_x_test = x_test[is_poison_test == 0]
clean_y_test = y_test[is_poison_test == 0]

clean_preds = np.argmax(classifier.predict(clean_x_test), axis=1)
clean_correct = np.sum(clean_preds == np.argmax(clean_y_test, axis=1))
clean_total = clean_y_test.shape[0]

clean_acc = clean_correct / clean_total
print("\nClean test set accuracy: %.2f%%" % (clean_acc * 100))
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Clean test set accuracy: 97.55%

# %%
# to be learned
# 图片&预测
c = 0 # class to display
i = 4 # image of the class to display

c_idx = np.where(np.argmax(clean_y_test,1) == c)[0][i] # index of the image in clean arrays

plt.imshow(clean_x_test[c_idx].squeeze())
plt.show()
clean_label = c
print("Prediction: " + str(clean_preds[c_idx]))

# %%
# pattern_img及预测
poison_x_test = x_test[is_poison_test]
poison_y_test = y_test[is_poison_test]

poison_preds = np.argmax(classifier.predict(poison_x_test), axis=1)
poison_correct = np.sum(poison_preds == np.argmax(poison_y_test, axis=1))
poison_total = poison_y_test.shape[0]

# Display image, label, and prediction for a poisoned image to see the backdoor working

c = 1 # class to display
i = 0 # image of the class to display

c_idx = np.where(np.argmax(poison_y_test,1) == c)[0][i] # index of the image in poison arrays

plt.imshow(poison_x_test[c_idx].squeeze())
plt.show()
poison_label = c
print("Prediction: " + str(poison_preds[c_idx]))

poison_acc = poison_correct / poison_total
print("\n Effectiveness of poison: %.2f%%" % (poison_acc * 100))
# Out:
# Prediction: 1
#
#  Effectiveness of poison: 100.00%

# %% [markdown]
# # defense

# %%
from activation_defence import ActivationDefence
import pprint

# %%
# 激活聚类 PCA降维
actDefence = ActivationDefence(classifier, x_train, y_train)
report, is_clean_lst = actDefence.detect_poison(nb_clusters=2, nd_dims=10, reduce="PCA") # PCA to be learned
pprint.pprint(report)
# Out:
# {'Class_0': {'cluster_0': {'ptc_data_in_cluster': 0.58,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.42,
#                            'suspicious_cluster': True}},
#  'Class_1': {'cluster_0': {'ptc_data_in_cluster': 0.67,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.33,
#                            'suspicious_cluster': True}},
#  'Class_2': {'cluster_0': {'ptc_data_in_cluster': 0.49,
#                            'suspicious_cluster': True},
#              'cluster_1': {'ptc_data_in_cluster': 0.51,
#                            'suspicious_cluster': False}},
#  'Class_3': {'cluster_0': {'ptc_data_in_cluster': 0.48,
#                            'suspicious_cluster': True},
#              'cluster_1': {'ptc_data_in_cluster': 0.52,
#                            'suspicious_cluster': False}},
#  'Class_4': {'cluster_0': {'ptc_data_in_cluster': 0.52,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.48,
#                            'suspicious_cluster': True}},
#  'Class_5': {'cluster_0': {'ptc_data_in_cluster': 0.56,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.44,
#                            'suspicious_cluster': True}},
#  'Class_6': {'cluster_0': {'ptc_data_in_cluster': 0.51,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.49,
#                            'suspicious_cluster': True}},
#  'Class_7': {'cluster_0': {'ptc_data_in_cluster': 0.59,
#                            'suspicious_cluster': False},
#              'cluster_1': {'ptc_data_in_cluster': 0.41,
#                            'suspicious_cluster': True}},
#  'Class_8': {'cluster_0': {'ptc_data_in_cluster': 0.47,
#                            'suspicious_cluster': True},
#              'cluster_1': {'ptc_data_in_cluster': 0.53,
#                            'suspicious_cluster': False}},
#  'Class_9': {'cluster_0': {'ptc_data_in_cluster': 0.39,
#                            'suspicious_cluster': True},
#              'cluster_1': {'ptc_data_in_cluster': 0.61,
#                            'suspicious_cluster': False}},
#  'cluster_analysis': 'smaller',
#  'clustering_method': 'KMeans',
#  'ex_re_threshold': None,
#  'generator': None,
#  'nb_clusters': 2,
#  'nb_dims': 10,
#  'reduce': 'PCA',
#  'suspicious_clusters': 10.0}
# /home/ubuntu/.local/lib/python3.8/site-packages/art/defences/detector/poison/clustering_analyzer.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray(all_assigned_clean), summary_poison_clusters, report

# %%
def plot_class_clusters(n_class, n_clusters):
    for q in range(n_clusters):
        plt.figure(1, figsize=(25, 25))
        plt.tight_layout()
        plt.subplot(1, n_clusters, q+1)
        plt.title("Class " + str(n_class) + ", Cluster " + str(q), fontsize=40)
        sprite = sprites_by_class[n_class][q]
        plt.imshow(sprite, interpolation='none')

# %%
sprites_by_class = actDefence.visualize_clusters(x_train, "./visualize/poison_class")
plot_class_clusters(1, 2)

# %%
# 优化一下代码、示例、展示图片等
